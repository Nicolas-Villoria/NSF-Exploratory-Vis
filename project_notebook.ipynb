# %% [markdown]
# # INFORMATION VISUALIZATION

# %% [markdown]
# # Project 2 – Exploratory visualization

# %% [markdown]
# ### By Nicolás Villoria and Oriol Fontanals

# %% [markdown]
# WRITE INTRODUCTION

# %% [markdown]
# WRITE REQUIREMENTS + PIP COMAND

# %%
#IMPORTS
import pandas as pd
import altair as alt

# %% [markdown]
# ## DATA PREPROCESSING:

# %% [markdown]
# WRITE PREPROCESSING INTRODUCTION

# %%
def load_raw_data() -> pd.DataFrame:
    nsf_grants_data = pd.read_csv("all_grants_with_termination.csv")
    return nsf_grants_data

# %%
#DELETE UNNECESSARY COLUMNS

def delete_unnecessary_columns(df: pd.DataFrame) -> pd.DataFrame:
    
    nsf_data_simplified = df.copy()

    cols_to_drop = [
        "agcy_id",
        "cfda_num",
        "org_code",
        "po_phone",
        "po_email",
        "po_sign_block_name",
        "awd_min_amd_letter_date",
        "awd_max_amd_letter_date",
        "awd_arra_amount",
        "awd_agcy_code",
        "fund_agcy_code",
        "pi_first_name",
        "pi_last_name",
        "pi_mid_init",
        "pi_full_name",
        "pi_email_addr",
        "nsf_id",
        "num_co_pis",
        "inst_street_address",
        "inst_country_name",
        "cong_dist_code",
        "st_cong_dist_code",
        "org_uei_num",
        "perf_st_code",
        "perf_zip_code",
        "perf_cong_dist",
        "perf_st_cong_dist",
        "perf_ctry_name",
        "pgm_ref_code",
        "pgm_ref_txt",
        "fund_oblg_fiscal_yr",
    ]

    nsf_data_simplified = nsf_data_simplified.drop(columns=[col for col in cols_to_drop if col in nsf_data_simplified.columns])
    return nsf_data_simplified

# %%
def save_processed_data(df: pd.DataFrame):
    """
    Save the processed dataframe to CSV file.

    Args:
        df: Processed dataframe
    """
 
    output_path = "nsf_data_clean.csv"
    df.to_csv(output_path, index=False)
    print(f"Processed data saved to {output_path}")

# %%
def main_processing_pipeline() -> pd.DataFrame:
    """
    Main processing pipeline that combines all cleaning steps.

    Returns:
        Fully processed dataframe ready for visualization
    """
    print("Loading raw data...")
    nsf_data = load_raw_data()
    print(nsf_data.head())

    print("Cleaning NSF data...")
    nsf_clean = delete_unnecessary_columns(nsf_data)
    print(nsf_clean.head())
    
    print("Saving processed data...")
    save_processed_data(nsf_clean)
    
    return nsf_clean

# %%
processed_data = main_processing_pipeline()
print("Data processing complete!")
processed_data.head()
# Out:
# Loading raw data...
# /var/folders/fz/940_y4bn321bf0gsxlpmw2qm0000gn/T/ipykernel_87409/2941316177.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   nsf_grants_data = pd.read_csv("all_grants_with_termination.csv")
#    year   awd_id agcy_id tran_type      awd_istr_txt  \
# 0  2020  1953228     NSF     Grant    Standard Grant
# 1  2020  1951215     NSF     Grant    Standard Grant
# 2  2020  1944914     NSF     Grant  Continuing Grant
# 3  2020  2014674     NSF     Grant    Standard Grant
# 4  2020  2019046     NSF     Grant    Standard Grant
#
#                                         awd_titl_txt cfda_num  org_code  \
# 0       APS Indigenous Language Manuscript Interface   47.075   4040000
# 1  SBIR Phase II:  Ultrathin Polymer Electrolyte ...   47.084  15030000
# 2  CAREER: Developing Spatially Organized Biomate...   47.049   3070000
# 3  SBIR Phase I:  Non-mechanical harvesting of wi...   47.084  15030000
# 4  MRI: Acquisition of a solid/liquid-state 700 M...   47.074   8080000
#
#        po_phone          po_email  ...  perf_st_name perf_zip_code  \
# 0           NaN               NaN  ...  Pennsylvania     191063387
# 1           NaN               NaN  ...      New York     148536007
# 2  7.032927e+09  nirosenz@nsf.gov  ...  Pennsylvania     180153195
# 3  7.032922e+09    rmehta@nsf.gov  ...    New Mexico     875054639
# 4           NaN               NaN  ...     Louisiana     708032701
#
#   perf_cong_dist  perf_st_cong_dist  perf_ctry_name pgm_ref_code  \
# 0            2.0               PA02   United States         7719
# 1           19.0               NY19   United States         8030
# 2            7.0               PA07   United States         1045
# 3            3.0               NM03   United States         8035
# 4            6.0               LA06   United States          NaN
#
#                       pgm_ref_txt  fund_oblg_fiscal_yr fund_oblg_amt  \
# 0                             DEL               2020.0      200131.0
# 1             Chemical Technology               2020.0      747653.0
# 2  CAREER-Faculty Erly Career Dev               2020.0      112015.0
# 3                Hardware Devices               2020.0      225000.0
# 4                             NaN               2020.0     1361751.0
#
#   terminated
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 56 columns]
# Cleaning NSF data...
#    year   awd_id tran_type      awd_istr_txt  \
# 0  2020  1953228     Grant    Standard Grant
# 1  2020  1951215     Grant    Standard Grant
# 2  2020  1944914     Grant  Continuing Grant
# 3  2020  2014674     Grant    Standard Grant
# 4  2020  2019046     Grant    Standard Grant
#
#                                         awd_titl_txt awd_eff_date  \
# 0       APS Indigenous Language Manuscript Interface   2020-08-01
# 1  SBIR Phase II:  Ultrathin Polymer Electrolyte ...   2020-05-01
# 2  CAREER: Developing Spatially Organized Biomate...   2020-02-15
# 3  SBIR Phase I:  Non-mechanical harvesting of wi...   2020-06-01
# 4  MRI: Acquisition of a solid/liquid-state 700 M...   2020-08-01
#
#   awd_exp_date  tot_intn_awd_amt  awd_amount dir_abbr  ... inst_city_name  \
# 0   2024-01-31          200131.0    200131.0      SBE  ...   PHILADELPHIA
# 1   2023-04-30          747653.0    747653.0      TIP  ...         ITHACA
# 2   2026-01-31          595370.0    745901.0      MPS  ...      BETHLEHEM
# 3   2021-11-30          225000.0    225000.0      TIP  ...       SANTA FE
# 4   2023-07-31         1361751.0   1361751.0      BIO  ...    BATON ROUGE
#
#   inst_state_code inst_state_name inst_zip_code  \
# 0              PA    Pennsylvania     191063309
# 1              NY        New York     148501247
# 2              PA    Pennsylvania     180153008
# 3              NM      New Mexico     875054639
# 4              LA       Louisiana     708030001
#
#                  org_lgl_bus_name                              perf_inst_name  \
# 0  AMERICAN PHILOSOPHICAL SOCIETY              American Philosophical Society
# 1                   ECOLECTRO INC                              Ecolectro, Inc
# 2               LEHIGH UNIVERSITY                           Lehigh University
# 3         THERMODYNAMIC FILMS LLC                         ThermoDynamic Films
# 4      LOUISIANA STATE UNIVERSITY  Louisiana State University and A&M College
#
#   perf_city_name  perf_st_name fund_oblg_amt terminated
# 0   Philadelphia  Pennsylvania      200131.0      False
# 1         Ithaca      New York      747653.0      False
# 2      Bethlehem  Pennsylvania      112015.0      False
# 3       Santa Fe    New Mexico      225000.0      False
# 4    Baton Rouge     Louisiana     1361751.0      False
#
# [5 rows x 25 columns]
# Saving processed data...
# Processed data saved to nsf_data_clean.csv
# Data processing complete!
# Processed data saved to nsf_data_clean.csv
# Data processing complete!
#    year   awd_id tran_type      awd_istr_txt  \
# 0  2020  1953228     Grant    Standard Grant
# 1  2020  1951215     Grant    Standard Grant
# 2  2020  1944914     Grant  Continuing Grant
# 3  2020  2014674     Grant    Standard Grant
# 4  2020  2019046     Grant    Standard Grant
#
#                                         awd_titl_txt awd_eff_date  \
# 0       APS Indigenous Language Manuscript Interface   2020-08-01
# 1  SBIR Phase II:  Ultrathin Polymer Electrolyte ...   2020-05-01
# 2  CAREER: Developing Spatially Organized Biomate...   2020-02-15
# 3  SBIR Phase I:  Non-mechanical harvesting of wi...   2020-06-01
# 4  MRI: Acquisition of a solid/liquid-state 700 M...   2020-08-01
#
#   awd_exp_date  tot_intn_awd_amt  awd_amount dir_abbr  ... inst_city_name  \
# 0   2024-01-31          200131.0    200131.0      SBE  ...   PHILADELPHIA
# 1   2023-04-30          747653.0    747653.0      TIP  ...         ITHACA
# 2   2026-01-31          595370.0    745901.0      MPS  ...      BETHLEHEM
# 3   2021-11-30          225000.0    225000.0      TIP  ...       SANTA FE
# 4   2023-07-31         1361751.0   1361751.0      BIO  ...    BATON ROUGE
#
#   inst_state_code inst_state_name inst_zip_code  \
# 0              PA    Pennsylvania     191063309
# 1              NY        New York     148501247
# 2              PA    Pennsylvania     180153008
# 3              NM      New Mexico     875054639
# 4              LA       Louisiana     708030001
#
#                  org_lgl_bus_name                              perf_inst_name  \
# 0  AMERICAN PHILOSOPHICAL SOCIETY              American Philosophical Society
# 1                   ECOLECTRO INC                              Ecolectro, Inc
# 2               LEHIGH UNIVERSITY                           Lehigh University
# 3         THERMODYNAMIC FILMS LLC                         ThermoDynamic Films
# 4      LOUISIANA STATE UNIVERSITY  Louisiana State University and A&M College
#
#   perf_city_name  perf_st_name fund_oblg_amt terminated
# 0   Philadelphia  Pennsylvania      200131.0      False
# 1         Ithaca      New York      747653.0      False
# 2      Bethlehem  Pennsylvania      112015.0      False
# 3       Santa Fe    New Mexico      225000.0      False
# 4    Baton Rouge     Louisiana     1361751.0      False
#
# [5 rows x 25 columns]

# %% [markdown]
# # Q1: How are the grants distributed by states every year?

# %%
# Load the cleaned data
df = pd.read_csv('nsf_data_clean.csv', low_memory=False)

# Check the data
print(f"Total grants: {len(df)}")
print(f"Years available: {sorted(df['year'].unique())}")
print(f"States: {df['inst_state_code'].nunique()}")
df.head()
# Out:
# Total grants: 70076
# Years available: [2020, 2021, 2022, 2023, 2024, 2025]
# States: 60
#    year   awd_id tran_type      awd_istr_txt  \
# 0  2020  1953228     Grant    Standard Grant
# 1  2020  1951215     Grant    Standard Grant
# 2  2020  1944914     Grant  Continuing Grant
# 3  2020  2014674     Grant    Standard Grant
# 4  2020  2019046     Grant    Standard Grant
#
#                                         awd_titl_txt awd_eff_date  \
# 0       APS Indigenous Language Manuscript Interface   2020-08-01
# 1  SBIR Phase II:  Ultrathin Polymer Electrolyte ...   2020-05-01
# 2  CAREER: Developing Spatially Organized Biomate...   2020-02-15
# 3  SBIR Phase I:  Non-mechanical harvesting of wi...   2020-06-01
# 4  MRI: Acquisition of a solid/liquid-state 700 M...   2020-08-01
#
#   awd_exp_date  tot_intn_awd_amt  awd_amount dir_abbr  ... inst_city_name  \
# 0   2024-01-31          200131.0    200131.0      SBE  ...   PHILADELPHIA
# 1   2023-04-30          747653.0    747653.0      TIP  ...         ITHACA
# 2   2026-01-31          595370.0    745901.0      MPS  ...      BETHLEHEM
# 3   2021-11-30          225000.0    225000.0      TIP  ...       SANTA FE
# 4   2023-07-31         1361751.0   1361751.0      BIO  ...    BATON ROUGE
#
#   inst_state_code inst_state_name inst_zip_code  \
# 0              PA    Pennsylvania     191063309
# 1              NY        New York     148501247
# 2              PA    Pennsylvania     180153008
# 3              NM      New Mexico     875054639
# 4              LA       Louisiana     708030001
#
#                  org_lgl_bus_name                              perf_inst_name  \
# 0  AMERICAN PHILOSOPHICAL SOCIETY              American Philosophical Society
# 1                   ECOLECTRO INC                              Ecolectro, Inc
# 2               LEHIGH UNIVERSITY                           Lehigh University
# 3         THERMODYNAMIC FILMS LLC                         ThermoDynamic Films
# 4      LOUISIANA STATE UNIVERSITY  Louisiana State University and A&M College
#
#   perf_city_name  perf_st_name fund_oblg_amt terminated
# 0   Philadelphia  Pennsylvania      200131.0      False
# 1         Ithaca      New York      747653.0      False
# 2      Bethlehem  Pennsylvania      112015.0      False
# 3       Santa Fe    New Mexico      225000.0      False
# 4    Baton Rouge     Louisiana     1361751.0      False
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Interactive Choropleth Map: Grants Distribution by State
#
# This visualization shows how NSF grants are geographically distributed across U.S. states:
# - **Year slider**: Select different years to see how the distribution changes over time
# - **Color intensity**: Darker colors indicate more grants
# - **Interactive tooltips**: Hover over states to see detailed grant statistics

# %%
from vega_datasets import data

# Prepare data - group by state and year
grants_by_state_year = df.groupby(['inst_state_code', 'year']).agg({
    'awd_id': 'count',
    'terminated': 'sum'
}).reset_index()

grants_by_state_year.columns = ['state', 'year', 'num_grants', 'terminated_grants']

# Calculate percentage of terminated grants
grants_by_state_year['terminated_pct'] = (
    grants_by_state_year['terminated_grants'] / grants_by_state_year['num_grants'] * 100
).round(2)

# Load US states geographic data
us_states = alt.topo_feature(data.us_10m.url, 'states')

# Create state FIPS mapping
state_fips = {
    'AL': 1, 'AK': 2, 'AZ': 4, 'AR': 5, 'CA': 6, 'CO': 8, 'CT': 9, 'DE': 10,
    'FL': 12, 'GA': 13, 'HI': 15, 'ID': 16, 'IL': 17, 'IN': 18, 'IA': 19,
    'KS': 20, 'KY': 21, 'LA': 22, 'ME': 23, 'MD': 24, 'MA': 25, 'MI': 26,
    'MN': 27, 'MS': 28, 'MO': 29, 'MT': 30, 'NE': 31, 'NV': 32, 'NH': 33,
    'NJ': 34, 'NM': 35, 'NY': 36, 'NC': 37, 'ND': 38, 'OH': 39, 'OK': 40,
    'OR': 41, 'PA': 42, 'RI': 44, 'SC': 45, 'SD': 46, 'TN': 47, 'TX': 48,
    'UT': 49, 'VT': 50, 'VA': 51, 'WA': 53, 'WV': 54, 'WI': 55, 'WY': 56,
    'DC': 11, 'PR': 72
}

# Add FIPS id to the dataframe
grants_by_state_year['id'] = grants_by_state_year['state'].map(state_fips)

# Remove rows without valid FIPS codes
grants_by_state_year = grants_by_state_year.dropna(subset=['id'])
grants_by_state_year['id'] = grants_by_state_year['id'].astype(int)

print(f"Data prepared for {len(grants_by_state_year)} state-year combinations")
print(f"\nYears available: {sorted(grants_by_state_year['year'].unique())}")
print(f"\nSample data:")
print(grants_by_state_year.head(10))
# Out:
# Data prepared for 312 state-year combinations
#
# Years available: [2020, 2021, 2022, 2023, 2024, 2025]
#
# Sample data:
#   state  year  num_grants  terminated_grants  terminated_pct  id
# 0    AK  2020          66                  0            0.00   2
# 1    AK  2021          64                  0            0.00   2
# 2    AK  2022          56                  1            1.79   2
# 3    AK  2023          49                  1            2.04   2
# 4    AK  2024          42                  2            4.76   2
# 5    AK  2025          26                  0            0.00   2
# 6    AL  2020         147                  0            0.00   1
# 7    AL  2021         132                  2            1.52   1
# 8    AL  2022         137                  3            2.19   1
# 9    AL  2023         166                  5            3.01   1

# %%
# Create year slider
year_slider = alt.binding_range(
    min=2020,
    max=2025,
    step=1,
    name='Year: '
)
year_param = alt.param(
    name='year_selection',
    value=2020,
    bind=year_slider
)

# Pivot data to wide format to allow lookup of all years
grants_wide = grants_by_state_year.pivot(index=['state', 'id'], columns='year', values=['num_grants', 'terminated_grants', 'terminated_pct']).reset_index()
grants_wide.columns = [f"{col[0]}_{col[1]}" if col[1] != '' else col[0] for col in grants_wide.columns]
grants_wide = grants_wide.fillna(0)

# Get min and max for color scale
min_grants = grants_by_state_year['num_grants'].min()
max_grants = grants_by_state_year['num_grants'].max()

# Define state coordinates for labels and PR
state_lookup = pd.DataFrame([
    {"id": 1, "state": "AL", "longitude": -86.9023, "latitude": 32.3182},
    {"id": 2, "state": "AK", "longitude": -153.3691, "latitude": 63.5888},
    {"id": 4, "state": "AZ", "longitude": -111.0937, "latitude": 34.0489},
    {"id": 5, "state": "AR", "longitude": -92.3731, "latitude": 35.2010},
    {"id": 6, "state": "CA", "longitude": -119.4179, "latitude": 36.7783},
    {"id": 8, "state": "CO", "longitude": -105.7821, "latitude": 39.5501},
    {"id": 9, "state": "CT", "longitude": -72.7554, "latitude": 41.6032},
    {"id": 10, "state": "DE", "longitude": -75.5277, "latitude": 38.9108},
    {"id": 11, "state": "DC", "longitude": -77.0369, "latitude": 38.9072},
    {"id": 12, "state": "FL", "longitude": -81.5158, "latitude": 27.6648},
    {"id": 13, "state": "GA", "longitude": -82.9071, "latitude": 32.1656},
    {"id": 15, "state": "HI", "longitude": -157.8583, "latitude": 21.3069},
    {"id": 16, "state": "ID", "longitude": -114.7420, "latitude": 44.0682},
    {"id": 17, "state": "IL", "longitude": -89.3985, "latitude": 40.6331},
    {"id": 18, "state": "IN", "longitude": -86.1349, "latitude": 40.2672},
    {"id": 19, "state": "IA", "longitude": -93.0977, "latitude": 41.8780},
    {"id": 20, "state": "KS", "longitude": -96.7265, "latitude": 38.5266},
    {"id": 21, "state": "KY", "longitude": -84.6701, "latitude": 37.6681},
    {"id": 22, "state": "LA", "longitude": -91.8749, "latitude": 31.1695},
    {"id": 23, "state": "ME", "longitude": -69.3819, "latitude": 44.6939},
    {"id": 24, "state": "MD", "longitude": -76.6413, "latitude": 39.0639},
    {"id": 25, "state": "MA", "longitude": -71.5301, "latitude": 42.2302},
    {"id": 26, "state": "MI", "longitude": -84.5467, "latitude": 43.3266},
    {"id": 27, "state": "MN", "longitude": -93.9196, "latitude": 45.6945},
    {"id": 28, "state": "MS", "longitude": -89.6787, "latitude": 32.7416},
    {"id": 29, "state": "MO", "longitude": -92.2896, "latitude": 38.4561},
    {"id": 30, "state": "MT", "longitude": -110.4544, "latitude": 46.9219},
    {"id": 31, "state": "NE", "longitude": -98.2680, "latitude": 41.1254},
    {"id": 32, "state": "NV", "longitude": -117.0554, "latitude": 38.3135},
    {"id": 33, "state": "NH", "longitude": -71.5639, "latitude": 43.4525},
    {"id": 34, "state": "NJ", "longitude": -74.5210, "latitude": 40.2989},
    {"id": 35, "state": "NM", "longitude": -106.2371, "latitude": 34.8405},
    {"id": 36, "state": "NY", "longitude": -74.9481, "latitude": 42.1657},
    {"id": 37, "state": "NC", "longitude": -79.8064, "latitude": 35.6301},
    {"id": 38, "state": "ND", "longitude": -99.7840, "latitude": 47.5289},
    {"id": 39, "state": "OH", "longitude": -82.7644, "latitude": 40.3888},
    {"id": 40, "state": "OK", "longitude": -97.0929, "latitude": 35.5653},
    {"id": 41, "state": "OR", "longitude": -122.0709, "latitude": 44.5720},
    {"id": 42, "state": "PA", "longitude": -77.2098, "latitude": 40.5908},
    {"id": 72, "state": "PR", "longitude": -75.5158, "latitude": 24.7663},
    {"id": 44, "state": "RI", "longitude": -71.5114, "latitude": 41.6809},
    {"id": 45, "state": "SC", "longitude": -80.9066, "latitude": 33.8569},
    {"id": 46, "state": "SD", "longitude": -99.4388, "latitude": 44.2998},
    {"id": 47, "state": "TN", "longitude": -86.6923, "latitude": 35.7478},
    {"id": 48, "state": "TX", "longitude": -97.5631, "latitude": 31.0545},
    {"id": 49, "state": "UT", "longitude": -111.8910, "latitude": 40.1500},
    {"id": 50, "state": "VT", "longitude": -72.7107, "latitude": 44.0459},
    {"id": 51, "state": "VA", "longitude": -78.1690, "latitude": 37.7693},
    {"id": 53, "state": "WA", "longitude": -121.4906, "latitude": 47.4009},
    {"id": 54, "state": "WV", "longitude": -80.9545, "latitude": 38.4912},
    {"id": 55, "state": "WI", "longitude": -89.6165, "latitude": 44.2685},
    {"id": 56, "state": "WY", "longitude": -107.3025, "latitude": 42.7559}
])

# Define east coast states that need offset labels
east_coast_states = ['NH', 'MA', 'RI', 'NJ', 'DE', 'DC']

# Create offset coordinates for east coast states
state_lookup['label_longitude'] = state_lookup.apply(
    lambda row: row['longitude'] + 2 if row['state'] in east_coast_states else row['longitude'],
    axis=1
)
state_lookup['label_latitude'] = state_lookup.apply(
    lambda row: row['latitude'] - 2 if row['state'] in east_coast_states else row['latitude'],
    axis=1
)

# Create the choropleth map
choropleth = alt.Chart(us_states).mark_geoshape(
    stroke='white',
    strokeWidth=0.5
).encode(
    color=alt.Color(
        'current_num_grants:Q',
        scale=alt.Scale(scheme='blues', domain=[min_grants, max_grants]),
        title='Number of Grants'
    ),
    tooltip=[
        alt.Tooltip('state:N', title='State'),
        alt.Tooltip('current_year:Q', title='Year'),
        alt.Tooltip('current_num_grants:Q', title='Total Grants', format=','),
        alt.Tooltip('current_terminated_grants:Q', title='Terminated Grants', format=','),
        alt.Tooltip('current_terminated_pct:Q', title='Termination %', format='.2f')
    ]
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(grants_wide, 'id', list(grants_wide.columns))
).transform_calculate(
    current_year="year_selection",
    current_num_grants="datum['num_grants_' + year_selection]",
    current_terminated_grants="datum['terminated_grants_' + year_selection]",
    current_terminated_pct="datum['terminated_pct_' + year_selection]"
).project(
    type='albersUsa'
)

# Create lines for east coast states
# Reduce lat and lon for better label placement
leader_lines = alt.Chart(state_lookup[state_lookup['state'].isin(east_coast_states)]).mark_rule(
    strokeWidth=1,
    color='gray',
    opacity=0.6,
    strokeDash=[3, 3]
).encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    longitude2='label_longitude:Q',
    latitude2='label_latitude:Q'
).project(
    type='albersUsa'
)

# Create text labels with offset positions
state_labels = alt.Chart(state_lookup).mark_text(
    fontSize=10,
    fontWeight='bold',
    color='black',
    opacity=0.7
).encode(
    longitude='label_longitude:Q',
    latitude='label_latitude:Q',
    text='state:N'
).project(
    type='albersUsa'
)

# Create an interactive circle for Puerto Rico
pr_data = state_lookup[state_lookup['state'] == 'PR'].copy()
pr_circle = alt.Chart(pr_data).mark_circle(
    size=400,
    opacity=0.8,
    stroke='white',
    strokeWidth=2
).encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    color=alt.Color(
        'current_num_grants:Q',
        scale=alt.Scale(scheme='blues', domain=[min_grants, max_grants]),
        legend=None
    ),
    tooltip=[
        alt.Tooltip('state:N', title='State'),
        alt.Tooltip('current_year:Q', title='Year'),
        alt.Tooltip('current_num_grants:Q', title='Total Grants', format=','),
        alt.Tooltip('current_terminated_grants:Q', title='Terminated Grants', format=','),
        alt.Tooltip('current_terminated_pct:Q', title='Termination %', format='.2f')
    ]
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(grants_wide, 'id', list(grants_wide.columns))
).transform_calculate(
    current_year="year_selection",
    current_num_grants="datum['num_grants_' + year_selection]",
    current_terminated_grants="datum['terminated_grants_' + year_selection]",
    current_terminated_pct="datum['terminated_pct_' + year_selection]"
).project(
    type='albersUsa'
)

# Combine all layers
final_map = (choropleth + leader_lines + state_labels + pr_circle).properties(
    width=800,
    height=500,
    title='NSF Grants Distribution by State and Year'
).add_params(
    year_param
)

final_map
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Q2: How are the grants distributed per directorates? And for a certain year?

# %%
# Explore directorate data
print("\nDirectorates in dataset:")
print(df['dir_abbr'].value_counts())
print(f"\nTotal directorates: {df['dir_abbr'].nunique()}")
# Out:
# Directorates in dataset:
# MPS     15090
# CSE     11343
# ENG      9814
# GEO      8522
# EDU      6836
# BIO      6726
# TIP      5387
# SBE      4967
# O/D      1274
# IRM        66
# BFA        34
# NSB        15
# OCIO        2
# Name: dir_abbr, dtype: int64
#
# Total directorates: 13

# %% [markdown]
# ### Interactive Bar Chart: Grants by Directorate
#
# This visualization shows the distribution of grants across NSF directorates with:
# - **Year selector**: Choose "All years" for aggregated data or select a specific year
# - **Metric selector**: Toggle between total grants and terminated grants
# - **Interactive hover**: Highlights the selected directorate with detailed information

# %%
# Prepare data aggregated by directorate and year
directorate_data = df.groupby(['dir_abbr', 'year']).agg({
    'awd_id': 'count',
    'terminated': lambda x: x.sum()  # Count terminated grants (terminated=True means 1)
}).reset_index()

directorate_data.columns = ['directorate', 'year', 'num_grants', 'terminated_grants']

# Convert year to string for consistency
directorate_data['year'] = directorate_data['year'].astype(str)

# Also prepare data for "All years"
directorate_all_years = df.groupby('dir_abbr').agg({
    'awd_id': 'count',
    'terminated': lambda x: x.sum()
}).reset_index()

directorate_all_years.columns = ['directorate', 'num_grants', 'terminated_grants']
directorate_all_years['year'] = 'All years'

# Combine both datasets
directorate_combined = pd.concat([
    directorate_data,
    directorate_all_years
], ignore_index=True)

print(directorate_combined.head(10))
print(f"\nYears available: {directorate_combined['year'].unique()}")
# Out:
#   directorate  year  num_grants  terminated_grants
# 0         BFA  2020          10                  0
# 1         BFA  2021          11                  0
# 2         BFA  2022          13                  0
# 3         BIO  2020        1420                  0
# 4         BIO  2021        1226                  9
# 5         BIO  2022        1186                 15
# 6         BIO  2023        1088                 22
# 7         BIO  2024        1021                 27
# 8         BIO  2025         785                  1
# 9         CSE  2020        2148                  0
#
# Years available: ['2020' '2021' '2022' '2023' '2024' '2025' 'All years']

# %%
# Create year dropdown selector
year_options = ['All years', '2020', '2021', '2022', '2023', '2024', '2025']

year_dropdown = alt.binding_select(
    options=year_options,
    name='Year: '
)
year_selection = alt.param(
    name='selected_year',
    value='All years',
    bind=year_dropdown
)

# Create metric selector (radio buttons)
metric_radio = alt.binding_radio(
    options=['num_grants', 'terminated_grants'],
    labels=['Total Grants', 'Terminated Grants'],
    name='Metric: '
)
metric_selection = alt.param(
    name='selected_metric',
    value='num_grants',
    bind=metric_radio
)

# Create hover selection for highlighting
hover = alt.selection_point(
    on='mouseover',
    fields=['directorate'],
    empty=False
)

# Create the bar chart
bar_chart = alt.Chart(directorate_combined).mark_bar().encode(
    x=alt.X(
        'directorate:N',
        sort='-y',
        title='Directorate',
        axis=alt.Axis(labelAngle=-45)
    ),
    y=alt.Y(
        'value:Q',
        title='Number of Grants'
    ),
    color=alt.condition(
        hover,
        alt.Color('directorate:N', legend=None, scale=alt.Scale(scheme='category20')),
        alt.value('lightgray')
    ),
    opacity=alt.condition(
        hover,
        alt.value(1.0),
        alt.value(0.7)
    ),
    tooltip=[
        alt.Tooltip('directorate:N', title='Directorate'),
        alt.Tooltip('year:N', title='Year'),
        alt.Tooltip('num_grants:Q', title='Total Grants', format=','),
        alt.Tooltip('terminated_grants:Q', title='Terminated Grants', format=',')
    ]
).transform_filter(
    alt.datum.year == year_selection
).transform_fold(
    ['num_grants', 'terminated_grants'],
    as_=['metric', 'value']
).transform_filter(
    alt.datum.metric == metric_selection
).properties(
    width=700,
    height=400,
    title='NSF Grants Distribution by Directorate'
).add_params(
    year_selection,
    metric_selection,
    hover
)

bar_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # Q3: Are the cancelled grants especially hitting a certain directorate?

# %% [markdown]
# ### Normalized Stacked Bar Chart: Termination Rates by Directorate
#
# This visualization shows whether grant terminations are concentrated in specific directorates:
# - **Normalized stacked bars (100%)**: Each bar shows the percentage of terminated vs. active grants per directorate
# - **Year range filter**: Use the slider to filter data by year range
# - **Interactive click**: Click on a directorate to see detailed statistics

# %%
# Prepare data for termination analysis
# Create a column for termination status
df_termination = df.copy()
df_termination['status'] = df_termination['terminated'].apply(lambda x: 'Terminated' if x else 'Active')

# Group by directorate, year, and status
termination_by_dir = df_termination.groupby(['dir_abbr', 'year', 'status']).size().reset_index(name='count')
termination_by_dir.columns = ['directorate', 'year', 'status', 'count']

print(termination_by_dir.head(20))
print(f"\nDirectorates: {termination_by_dir['directorate'].unique()}")
print(f"\nYears: {sorted(termination_by_dir['year'].unique())}")
# Out:
#    directorate  year      status  count
# 0          BFA  2020      Active     10
# 1          BFA  2021      Active     11
# 2          BFA  2022      Active     13
# 3          BIO  2020      Active   1420
# 4          BIO  2021      Active   1217
# 5          BIO  2021  Terminated      9
# 6          BIO  2022      Active   1171
# 7          BIO  2022  Terminated     15
# 8          BIO  2023      Active   1066
# 9          BIO  2023  Terminated     22
# 10         BIO  2024      Active    994
# 11         BIO  2024  Terminated     27
# 12         BIO  2025      Active    784
# 13         BIO  2025  Terminated      1
# 14         CSE  2020      Active   2148
# 15         CSE  2021      Active   1861
# 16         CSE  2021  Terminated     21
# 17         CSE  2022      Active   1942
# 18         CSE  2022  Terminated     33
# 19         CSE  2023      Active   2009
#
# Directorates: ['BFA' 'BIO' 'CSE' 'EDU' 'ENG' 'GEO' 'IRM' 'MPS' 'NSB' 'O/D' 'OCIO' 'SBE'
#  'TIP']
#
# Years: [2020, 2021, 2022, 2023, 2024, 2025]
#
# Directorates: ['BFA' 'BIO' 'CSE' 'EDU' 'ENG' 'GEO' 'IRM' 'MPS' 'NSB' 'O/D' 'OCIO' 'SBE'
#  'TIP']
#
# Years: [2020, 2021, 2022, 2023, 2024, 2025]

# %%
# Create year range slider
year_range_slider = alt.binding_range(
    min=2020,
    max=2025,
    step=1,
    name='Year Range Start: '
)
year_range_start = alt.param(
    name='year_start',
    value=2020,
    bind=year_range_slider
)

year_range_slider_end = alt.binding_range(
    min=2020,
    max=2025,
    step=1,
    name='Year Range End: '
)
year_range_end = alt.param(
    name='year_end',
    value=2025,
    bind=year_range_slider_end
)

# Base chart with filtering
base = alt.Chart(termination_by_dir).transform_filter(
    (alt.datum.year >= year_range_start) & (alt.datum.year <= year_range_end)
).transform_aggregate(
    count='sum(count)',
    groupby=['directorate', 'status']
).transform_calculate(
    order="datum.status == 'Terminated' ? 0 : 1"
)


# Create main stacked bar chart (normalized percentage view)
stacked_chart = base.transform_joinaggregate(
    total='sum(count)',
    groupby=['directorate']
).transform_calculate(
    percentage='datum.count / datum.total * 100'
).mark_bar().encode(
    x=alt.X('directorate:N', title='Directorate', sort='-y', axis=alt.Axis(labelAngle=-45)),
    y=alt.Y('sum(count):Q', title='Number of Grants', stack='normalize'),
    color=alt.Color('status:N', 
                    scale=alt.Scale(domain=['Active', 'Terminated'], 
                                  range=['#2ecc71', '#e74c3c']),
                    title='Grant Status'),
    order=alt.Order('order:Q'),
    tooltip=[
        alt.Tooltip('directorate:N', title='Directorate'),
        alt.Tooltip('status:N', title='Status'),
        alt.Tooltip('count:Q', title='Number of Grants', format=','),
        alt.Tooltip('percentage:Q', title='Percentage', format='.2f')
    ]
).properties(
    width=700,
    height=400,
    title='Grant Termination Rates by Directorate (Normalized to 100%)'
).add_params(
    year_range_start,
    year_range_end
)

# Combine main chart with detail panel
final_chart = (stacked_chart).resolve_scale(
    color='shared'
)

final_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Evolution of Terminated Grants Over Time by Directorate
#
# This interactive line chart shows how terminated grants evolved over the years for each directorate:
# - **Multi-line view**: Each line represents a directorate
# - **Interactive hover**: Hover over the chart to see exact values for all directorates at that year
# - **Details on demand**: Year ruler and values appear when hovering

# %%
# Prepare data for line chart - terminated grants by directorate and year
terminated_evolution = df.groupby(['dir_abbr', 'year']).agg({
    'terminated': lambda x: x.sum()
}).reset_index()
terminated_evolution.columns = ['directorate', 'year', 'terminated_grants']

# Filter out directorates with very few grants for cleaner visualization
main_directorates = ['MPS', 'CSE', 'ENG', 'GEO', 'EDU', 'BIO', 'TIP', 'SBE']
terminated_evolution_filtered = terminated_evolution[terminated_evolution['directorate'].isin(main_directorates)]

print(terminated_evolution_filtered.head(20))
print(f"\nDirectorates included: {sorted(terminated_evolution_filtered['directorate'].unique())}")
# Out:
#    directorate  year  terminated_grants
# 3          BIO  2020                  0
# 4          BIO  2021                  9
# 5          BIO  2022                 15
# 6          BIO  2023                 22
# 7          BIO  2024                 27
# 8          BIO  2025                  1
# 9          CSE  2020                  0
# 10         CSE  2021                 21
# 11         CSE  2022                 33
# 12         CSE  2023                 41
# 13         CSE  2024                 19
# 14         CSE  2025                  2
# 15         EDU  2020                 47
# 16         EDU  2021                128
# 17         EDU  2022                161
# 18         EDU  2023                212
# 19         EDU  2024                180
# 20         EDU  2025                 13
# 21         ENG  2020                  2
# 22         ENG  2021                  8
#
# Directorates included: ['BIO', 'CSE', 'EDU', 'ENG', 'GEO', 'MPS', 'SBE', 'TIP']

# %%
# Create a selection that chooses the nearest point based on year
nearest = alt.selection_point(
    nearest=True, 
    on='mouseover',
    fields=['year'], 
    empty=False
)

# The basic line chart
line = alt.Chart(terminated_evolution_filtered).mark_line(
    interpolate='monotone',
    strokeWidth=2
).encode(
    x=alt.X('year:Q', title='Year', axis=alt.Axis(format='d')),
    y=alt.Y('terminated_grants:Q', title='Number of Terminated Grants'),
    color=alt.Color('directorate:N', 
                   title='Directorate',
                   scale=alt.Scale(scheme='category10'))
)

# Transparent selectors across the chart
selectors = alt.Chart(terminated_evolution_filtered).mark_point().encode(
    x='year:Q',
    opacity=alt.value(0),
).add_params(nearest)

# Draw points on the lines, and highlight based on selection
points = line.mark_point(size=80).encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(
    align='left', 
    dx=10, 
    dy=0,
    fontSize=11
).encode(
    text=alt.condition(nearest, 'terminated_grants:Q', alt.value(' '))
)

# Draw a vertical rule at the location of the selection
rules = alt.Chart(terminated_evolution_filtered).mark_rule(
    color='gray',
    strokeWidth=1
).encode(
    x='year:Q',
).transform_filter(nearest)

# Combine all layers
evolution_chart = alt.layer(
    line, selectors, points, rules, text
).properties(
    width=700,
    height=400,
    title='Evolution of Terminated Grants by Directorate (2020-2025)'
).configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_legend(
    labelFontSize=12,
    titleFontSize=13
)

evolution_chart
# Out:
# alt.LayerChart(...)
